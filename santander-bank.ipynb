# %% [markdown]
# **Importing libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# **Reading Files**

# %%
data_train = pd.read_csv("/kaggle/input/santander-customer-transaction-prediction-dataset/train.csv")
data_test = pd.read_csv("/kaggle/input/santander-customer-transaction-prediction-dataset/test.csv"
)

# %%
data_train.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250  ...   4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# ...

# %% [markdown]
# **Data Exploration**

# %%
data_test.head()
# Out:
#   ID_code    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  test_0  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 1  test_1   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 2  test_2   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 3  test_3   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 4  test_4  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#      var_7   var_8  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.2675  2.1337  ...  -2.1556  11.8495  -1.4300   2.4508  13.7112   2.4669
# 1  18.6316 -4.4131  ...  10.6165   8.8349   0.9403  10.1282  15.5765   0.4773
# 2  20.2537  1.5233  ...  -0.7484  10.9935   1.9803   2.1800  12.9813   2.1281
# 3  20.5660  3.3755  ...   9.5702   9.0766   1.6580   3.5813  15.1874   3.1656
# 4  10.6048  2.9890  ...   4.2259   9.1723   1.2835   3.3778  19.5542  -0.2860
#
#    var_196  var_197  var_198  var_199
# ...

# %%
data_train.shape , data_test.shape
# Out:
# ((200000, 202), (200000, 201))

# %%
data_train.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 202 entries, ID_code to var_199
# dtypes: float64(200), int64(1), object(1)
# memory usage: 308.2+ MB

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 201 entries, ID_code to var_199
# dtypes: float64(200), object(1)
# memory usage: 306.7+ MB

# %%
data_train.isnull().sum().max() #we dont have nulls in train data
# Out:
# 0

# %%
data_test.isnull().sum().max() #we dont have nulls in test data
# Out:
# 0

# %% [markdown]
# **Data Visulaziation**

# %%
# Count the occurrences of each target value
target_counts = data_train["target"].value_counts()

# Create a bar plot
plt.bar([0, 1], target_counts.values,color=["r","g"])

# Set x-tick labels
plt.xticks([0, 1])

# Set labels and title
plt.xlabel("Target")
plt.ylabel("Count")
plt.title("Target Distribution")

# Show the plot
plt.show()

# %%
#drop Id code to complete analysis
data_train=data_train.drop(["ID_code"],axis=1)
data_test=data_test.drop(["ID_code"],axis=1)


# Calculate correlation
cor = data_train.corr()
cor.head(10)
# Out:
#           target     var_0     var_1     var_2     var_3     var_4     var_5  \
# target  1.000000  0.052390  0.050343  0.055870  0.011055  0.010915  0.030979
# var_0   0.052390  1.000000 -0.000544  0.006573  0.003801  0.001326  0.003046
# var_1   0.050343 -0.000544  1.000000  0.003980  0.000010  0.000303 -0.000902
# var_2   0.055870  0.006573  0.003980  1.000000  0.001001  0.000723  0.001569
# var_3   0.011055  0.003801  0.000010  0.001001  1.000000 -0.000322  0.003253
# var_4   0.010915  0.001326  0.000303  0.000723 -0.000322  1.000000 -0.001368
# var_5   0.030979  0.003046 -0.000902  0.001569  0.003253 -0.001368  1.000000
# var_6   0.066731  0.006983  0.003258  0.000883 -0.000774  0.000049  0.002588
# var_7  -0.003025  0.002429  0.001511 -0.000991  0.002500  0.004549 -0.000995
# var_8   0.019584  0.004962  0.004098  0.002648  0.003553  0.001194  0.000147
#
#            var_6     var_7     var_8  ...   var_190   var_191   var_192  \
# ...

# %%
#correlation matrix
f, ax= plt.subplots(figsize=(15,10))
sns.heatmap(cor)
plt.show()

# %%
# Measuring top 10 correlated features
k = 11
top10features = cor.nlargest(k, "target")["target"].index
top10corr = data_train[top10features].corr()

sns.heatmap(top10corr, annot=True, fmt=".2f", linewidth=.7)
# Out:
# <Axes: >

# %%
#measuring bottom 10 features
k = 11
bottom10features = cor.nsmallest(k, "target")["target"].index
bottom10corr = data_train[bottom10features].corr()

#adding column
bottom10features = list(bottom10features) + ["target"]

sns.heatmap(data_train[bottom10features].corr(), annot=True, fmt=".2f", linewidth=.7)
# Out:
# <Axes: >

# %% [markdown]
# **Creating Model**

# %%
x= data_train.drop(["target"],axis=1)
y= data_train["target"]

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,train_size=0.75,shuffle=True,random_state=42) #spliting x,y

# %%
#difining Models

model1= LogisticRegression()
model2= GradientBoostingClassifier()

# %%
def testing(model):
  model.fit(x_train,y_train)
  pred = model.predict(x_test)
  accuracy = accuracy_score(pred,y_test)
  print("Model :" ,model)
  print ("accuracy score is \n", accuracy)

# %%
testing(model1)
# Out:
# Model : LogisticRegression()
# accuracy score is
#  0.90982

# %%
testing(model2) #90.4%

# %% [markdown]
# **Logistic Regression is the best model**

# %%
#using algorithm in test data
Logistic_Regression = LogisticRegression()
Logistic_Regression.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
predicting= Logistic_Regression.predict(data_test)

# %%
(predicting)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#adding predicting in data_test dataframe
data_test['predicting'] = predicting

# %%
data_test.head()
# Out:
#      var_0    var_1    var_2   var_3    var_4   var_5   var_6    var_7  \
# 0  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493  18.2675
# 1   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196  18.6316
# 2   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950  20.2537
# 3   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397  20.5660
# 4  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595  10.6048
#
#     var_8   var_9  ...  var_191  var_192  var_193  var_194  var_195  var_196  \
# 0  2.1337  8.8100  ...  11.8495  -1.4300   2.4508  13.7112   2.4669   4.3654
# 1 -4.4131  5.9739  ...   8.8349   0.9403  10.1282  15.5765   0.4773  -1.4852
# 2  1.5233  8.3442  ...  10.9935   1.9803   2.1800  12.9813   2.1281  -7.1086
# 3  3.3755  7.4578  ...   9.0766   1.6580   3.5813  15.1874   3.1656   3.9567
# 4  2.9890  7.1437  ...   9.1723   1.2835   3.3778  19.5542  -0.2860  -5.1612
#
#    var_197  var_198  var_199  predicting
# ...
