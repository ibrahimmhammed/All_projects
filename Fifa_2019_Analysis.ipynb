# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrahimmhammed/All_projects/blob/main/Fifa_2019_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly as py
import plotly.graph_objs as go
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Reading File

# %%
df1 = pd.read_csv("//content//data.csv")

# %% [markdown]
# # Data Exploration

# %%
df1.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
#  13  Special                   18207 non-null  int64
#  14  Preferred Foot            18159 non-null  object
#  15  International Reputation  18159 non-null  float64
#  16  Weak Foot                 18159 non-null  float64
#  17  Skill Moves               18159 non-null  float64
#  18  Work Rate                 18159 non-null  object
#  19  Body Type                 18159 non-null  object
#  20  Real Face                 18159 non-null  object
#  21  Position                  18147 non-null  object
#  22  Jersey Number             18147 non-null  float64
#  23  Joined                    16654 non-null  object
#  24  Loaned From               1264 non-null   object
#  25  Contract Valid Until      17918 non-null  object
#  26  Height                    18159 non-null  object
#  27  Weight                    18159 non-null  object
#  28  LS                        16122 non-null  object
#  29  ST                        16122 non-null  object
#  30  RS                        16122 non-null  object
#  31  LW                        16122 non-null  object
#  32  LF                        16122 non-null  object
#  33  CF                        16122 non-null  object
#  34  RF                        16122 non-null  object
#  35  RW                        16122 non-null  object
#  36  LAM                       16122 non-null  object
#  37  CAM                       16122 non-null  object
#  38  RAM                       16122 non-null  object
#  39  LM                        16122 non-null  object
#  40  LCM                       16122 non-null  object
#  41  CM                        16122 non-null  object
#  42  RCM                       16122 non-null  object
#  43  RM                        16122 non-null  object
#  44  LWB                       16122 non-null  object
#  45  LDM                       16122 non-null  object
#  46  CDM                       16122 non-null  object
#  47  RDM                       16122 non-null  object
#  48  RWB                       16122 non-null  object
#  49  LB                        16122 non-null  object
#  50  LCB                       16122 non-null  object
#  51  CB                        16122 non-null  object
#  52  RCB                       16122 non-null  object
#  53  RB                        16122 non-null  object
#  54  Crossing                  18159 non-null  float64
#  55  Finishing                 18159 non-null  float64
#  56  HeadingAccuracy           18159 non-null  float64
#  57  ShortPassing              18159 non-null  float64
#  58  Volleys                   18159 non-null  float64
#  59  Dribbling                 18159 non-null  float64
#  60  Curve                     18159 non-null  float64
#  61  FKAccuracy                18159 non-null  float64
#  62  LongPassing               18159 non-null  float64
#  63  BallControl               18159 non-null  float64
#  64  Acceleration              18159 non-null  float64
#  65  SprintSpeed               18159 non-null  float64
#  66  Agility                   18159 non-null  float64
#  67  Reactions                 18159 non-null  float64
#  68  Balance                   18159 non-null  float64
#  69  ShotPower                 18159 non-null  float64
#  70  Jumping                   18159 non-null  float64
#  71  Stamina                   18159 non-null  float64
#  72  Strength                  18159 non-null  float64
#  73  LongShots                 18159 non-null  float64
#  74  Aggression                18159 non-null  float64
#  75  Interceptions             18159 non-null  float64
#  76  Positioning               18159 non-null  float64
#  77  Vision                    18159 non-null  float64
#  78  Penalties                 18159 non-null  float64
#  79  Composure                 18159 non-null  float64
#  80  Marking                   18159 non-null  float64
#  81  StandingTackle            18159 non-null  float64
#  82  SlidingTackle             18159 non-null  float64
#  83  GKDiving                  18159 non-null  float64
#  84  GKHandling                18159 non-null  float64
#  85  GKKicking                 18159 non-null  float64
#  86  GKPositioning             18159 non-null  float64
#  87  GKReflexes                18159 non-null  float64
#  88  Release Clause            16643 non-null  object
# dtypes: float64(38), int64(6), object(45)
# memory usage: 12.4+ MB

# %%
df1.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# std      272.586016                  0.394031      0.660456      0.756164
# min      731.000000                  1.000000      1.000000      1.000000
# 25%     1457.000000                  1.000000      3.000000      2.000000
# 50%     1635.000000                  1.000000      3.000000      2.000000
# 75%     1787.000000                  1.000000      3.000000      3.000000
# max     2346.000000                  5.000000      5.000000      5.000000
#
#        Jersey Number  ...     Penalties     Composure       Marking  \
# count   18147.000000  ...  18159.000000  18159.000000  18159.000000
# mean       19.546096  ...     48.548598     58.648274     47.281623
# std        15.947765  ...     15.704053     11.436133     19.904397
# min         1.000000  ...      5.000000      3.000000      3.000000
# 25%         8.000000  ...     39.000000     51.000000     30.000000
# 50%        17.000000  ...     49.000000     60.000000     53.000000
# 75%        26.000000  ...     60.000000     67.000000     64.000000
# max        99.000000  ...     92.000000     96.000000     94.000000
#
#        StandingTackle  SlidingTackle      GKDiving    GKHandling  \
# count    18159.000000   18159.000000  18159.000000  18159.000000
# mean        47.697836      45.661435     16.616223     16.391596
# std         21.664004      21.289135     17.695349     16.906900
# min          2.000000       3.000000      1.000000      1.000000
# 25%         27.000000      24.000000      8.000000      8.000000
# 50%         55.000000      52.000000     11.000000     11.000000
# 75%         66.000000      64.000000     14.000000     14.000000
# max         93.000000      91.000000     90.000000     92.000000
#
#           GKKicking  GKPositioning    GKReflexes
# count  18159.000000   18159.000000  18159.000000
# mean      16.232061      16.388898     16.710887
# std       16.502864      17.034669     17.955119
# min        1.000000       1.000000      1.000000
# 25%        8.000000       8.000000      8.000000
# 50%       11.000000      11.000000     11.000000
# 75%       14.000000      14.000000     14.000000
# max       91.000000      90.000000     94.000000
#
# [8 rows x 44 columns]

# %%
df1.describe(include="O")
# Out:
#                 Name                                           Photo  \
# count          18207                                           18207
# unique         17194                                           18207
# top     J. Rodríguez  https://cdn.sofifa.org/players/4/19/158023.png
# freq              11                                               1
#
#        Nationality                                 Flag          Club  \
# count        18207                                18207         17966
# unique         164                                  164           651
# top        England  https://cdn.sofifa.org/flags/14.png  FC Barcelona
# freq          1662                                 1662            33
#
#                                            Club Logo  Value   Wage  \
# count                                          18207  18207  18207
# unique                                           679    217    144
# top     https://cdn.sofifa.org/teams/2/light/241.png  €1.1M    €1K
# freq                                              33    431   4900
#
#        Preferred Foot       Work Rate  ...    LDM    CDM    RDM    RWB     LB  \
# count           18159           18159  ...  16122  16122  16122  16122  16122
# unique              2               9  ...     99     99     99     95     98
# top             Right  Medium/ Medium  ...   62+2   62+2   62+2   61+2   61+2
# freq            13948            9810  ...    660    660    660    713    669
#
#           LCB     CB    RCB     RB Release Clause
# count   16122  16122  16122  16122          16643
# unique    108    108    108     98           1244
# top      63+2   63+2   63+2   61+2          €1.1M
# freq      634    634    634    669            557
#
# [4 rows x 45 columns]

# %% [markdown]
# We have too many features, so Let us only select some important features

# %%
imp_features = ['Name',
                   'Age','Overall',
                   'Nationality',
                   'Flag', 'LongPassing',
                'Club',
                   'BallControl',
                   'Acceleration',
                   'SprintSpeed',
                   'Agility',
                   'Reactions',
                   'Balance',
                   'ShotPower',
                   'Jumping',
                   'Stamina',
                   'Strength',
                   'LongShots',
                   'Aggression',
                   'Interceptions',
                   'Positioning',
                   'Vision',
                   'Penalties',
                   'Composure',
                   'Marking',
                   'StandingTackle',
                   'SlidingTackle',
                   'GKDiving',
                   'GKHandling',
                   'GKKicking',
                   'GKPositioning',
                   'GKReflexes','Position', 'Crossing', 'Volleys', 'HeadingAccuracy', 'ShortPassing', 'FKAccuracy', 'Finishing', 'Curve', 'Dribbling']

# %%
df = pd.DataFrame(df1 , columns = imp_features) #new df contains important features only

# %%
df.shape
# Out:
# (18207, 41)

# %% [markdown]
# # Data Analysis

# %%
plt.figure(figsize = (15 , 6))
df['Age'].plot(kind = 'hist' , bins = 50)
plt.title('Age of players')
plt.show()
#distribution of ages

# %%
cor = df.corr()

# Select the top 11 features with the highest correlation with "Age"
top_corr_features = cor.nlargest(11, "Age")["Age"].index

# Extract the actual correlation matrix for the top features
top_corr = df[top_corr_features].corr()

# Create a heatmap
plt.figure(figsize=(20, 5))
sns.heatmap(top_corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.show()

# %%
#Detailed Analysis of correlation (top vals)
top_vals = ['Overall' , 'Composure' , 'Strength','Aggression' , 'Interceptions' , 'FKAccuracy' ,
       'Vision','Reactions','LongPassing','Jumping']
for feature in top_vals:
    plt.figure()
    sns.regplot(x  = 'Age' , y = feature , data = df ,
                        color = 'red')

# %%
# Select the bottom 11 features with the smallest correlation with "Age"
bottom_corr_features = cor["Age"].nsmallest(10).index

# Include the "Age" column in the selected features
bottom_corr_features = bottom_corr_features.union(["Age"])

# Extract the actual correlation matrix for the bottom features
bottom_corr = df[bottom_corr_features].corr()

# Create a heatmap
plt.figure(figsize=(20, 5))
sns.heatmap(bottom_corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.show()

# %%
#Detailed Analysis of correlation (bottom vals)
bottom_vals = ['Acceleration' , 'Agility' , 'Balance','BallControl' , 'Dribbling' , 'Finishing' ,
       'GKDiving','Positioning','SprintSpeed','Stamina']
for feature in bottom_vals:
    plt.figure()
    sns.regplot(x  = 'Age' , y = feature , data = df ,
                        color = 'blue')

# %% [markdown]
# # Lets see oldest and youngest players

# %%
df.sort_values("Age").nlargest(columns=("Age"),n=5) #top 5 oldest players
# Out:
#                 Name  Age  Overall        Nationality  \
# 4741        O. Pérez   45       71             Mexico
# 18183  K. Pilkington   44       48            England
# 17726      T. Warner   44       53  Trinidad & Tobago
# 10545    S. Narazaki   42       65              Japan
# 1120       J. Villar   41       77           Paraguay
#
#                                        Flag  LongPassing                Club  \
# 4741    https://cdn.sofifa.org/flags/83.png         27.0             Pachuca
# 18183   https://cdn.sofifa.org/flags/14.png         13.0    Cambridge United
# 17726   https://cdn.sofifa.org/flags/93.png         24.0  Accrington Stanley
# 10545  https://cdn.sofifa.org/flags/163.png         28.0      Nagoya Grampus
# 1120    https://cdn.sofifa.org/flags/58.png         22.0                 NaN
#
#        BallControl  Acceleration  SprintSpeed  ...  GKReflexes  Position  \
# 4741          23.0          60.0         57.0  ...        74.0        GK
# 18183         16.0          15.0         17.0  ...        46.0        GK
# 17726         27.0          23.0         21.0  ...        44.0        GK
# 10545         30.0          52.0         56.0  ...        63.0        GK
# 1120          24.0          31.0         32.0  ...        77.0        GK
#
#        Crossing  Volleys  HeadingAccuracy  ShortPassing  FKAccuracy  \
# 4741       19.0     13.0             24.0          26.0        20.0
# 18183      11.0     11.0             12.0          18.0        13.0
# 17726      19.0     15.0             15.0          24.0        12.0
# 10545      23.0     19.0             23.0          29.0        40.0
# 1120       14.0      8.0             12.0          30.0        22.0
#
#        Finishing  Curve  Dribbling
# 4741        14.0   12.0       12.0
# 18183       12.0   12.0       11.0
# 17726       13.0   14.0       14.0
# 10545       11.0   22.0       30.0
# 1120        12.0   15.0       21.0
#
# [5 rows x 41 columns]

# %%
df.sort_values("Age").nsmallest(columns=("Age"),n=5) #top 5 youngest players
# Out:
#               Name  Age  Overall Nationality  \
# 18206    G. Nugent   16       46     England
# 17743    J. Olstad   16       52      Norway
# 13293  H. Massengo   16       62      France
# 16081  J. Italiano   16       58   Australia
# 18166     N. Ayéva   16       48      Sweden
#
#                                        Flag  LongPassing             Club  \
# 18206   https://cdn.sofifa.org/flags/14.png         44.0  Tranmere Rovers
# 17743   https://cdn.sofifa.org/flags/36.png         31.0  Sarpsborg 08 FF
# 13293   https://cdn.sofifa.org/flags/18.png         61.0        AS Monaco
# 16081  https://cdn.sofifa.org/flags/195.png         57.0      Perth Glory
# 18166   https://cdn.sofifa.org/flags/46.png         30.0        Örebro SK
#
#        BallControl  Acceleration  SprintSpeed  ...  GKReflexes  Position  \
# 18206         51.0          57.0         55.0  ...         9.0        CM
# 17743         53.0          70.0         68.0  ...         8.0        ST
# 13293         58.0          62.0         62.0  ...        15.0       CDM
# 16081         56.0          80.0         72.0  ...         5.0        LM
# 18166         46.0          65.0         66.0  ...         6.0        ST
#
#        Crossing  Volleys  HeadingAccuracy  ShortPassing  FKAccuracy  \
# 18206      41.0     30.0             46.0          48.0        34.0
# 17743      28.0     41.0             49.0          48.0        31.0
# 13293      52.0     39.0             60.0          66.0        44.0
# 16081      43.0     35.0             36.0          61.0        36.0
# 18166      34.0     40.0             42.0          43.0        32.0
#
#        Finishing  Curve  Dribbling
# 18206       34.0   40.0       43.0
# 17743       53.0   36.0       51.0
# 13293       39.0   46.0       53.0
# 16081       50.0   41.0       59.0
# 18166       47.0   45.0       50.0
#
# [5 rows x 41 columns]

# %%
df['Nationality'].value_counts()
# Out:
# England                 1662
# Germany                 1198
# Spain                   1072
# Argentina                937
# France                   914
#                         ...
# New Caledonia              1
# Fiji                       1
# São Tomé & Príncipe        1
# United Arab Emirates       1
# Botswana                   1
# Name: Nationality, Length: 164, dtype: int64

# %% [markdown]
# Lets go deeper and see Egyption Players

# %%
egy= df.loc[df['Nationality'] =="Egypt"]
egy
#showing all Egyption players in df
# Out:
#                  Name  Age  Overall Nationality  \
# 26           M. Salah   26       88       Egypt
# 752         Trezeguet   23       78       Egypt
# 959         M. Elneny   25       77       Egypt
# 1517        A. Hegazi   27       76       Egypt
# 2241        A. Hassan   25       74       Egypt
# 2259          Kahraba   24       74       Egypt
# 2334         R. Sobhi   21       74       Egypt
# 3310    A. Elmohamady   30       72       Egypt
# 3616         A. Warda   24       72       Egypt
# 3929        A. Ghazal   26       72       Egypt
# 4044         A. Tarek   26       71       Egypt
# 4217        Shikabala   32       71       Egypt
# 4504       A. El Said   32       71       Egypt
# 5614         A. Fathi   33       70       Egypt
# 5913         M. Hamdy   23       69       Egypt
# 5944         S. Morsy   26       69       Egypt
# 6021        A. Ashraf   27       69       Egypt
# 6407        S. Ekramy   34       69       Egypt
# 6717          A. Gabr   29       68       Egypt
# 6804         O. Gaber   26       68       Egypt
# 7102   M. Abdul Shafy   33       68       Egypt
# 8325        A. El-Abd   33       67       Egypt
# 8441         T. Hamed   29       67       Egypt
# 9165    M. El-Shenawy   29       66       Egypt
# 9228      H. El Sayed   26       66       Egypt
# 9297          M. Awad   25       66       Egypt
# 9514      A. Jakobsen   24       66       Egypt
# 9665         K. Hafez   22       66       Egypt
# 9911        M. Mohsen   29       66       Egypt
# 10672         M. Atwa   27       65       Egypt
# 13891      A. Mostafa   20       62       Egypt
#
#                                        Flag  LongPassing  \
# 26     https://cdn.sofifa.org/flags/111.png         72.0
# 752    https://cdn.sofifa.org/flags/111.png         72.0
# 959    https://cdn.sofifa.org/flags/111.png         77.0
# 1517   https://cdn.sofifa.org/flags/111.png         54.0
# 2241   https://cdn.sofifa.org/flags/111.png         46.0
# 2259   https://cdn.sofifa.org/flags/111.png         59.0
# 2334   https://cdn.sofifa.org/flags/111.png         67.0
# 3310   https://cdn.sofifa.org/flags/111.png         69.0
# 3616   https://cdn.sofifa.org/flags/111.png         70.0
# 3929   https://cdn.sofifa.org/flags/111.png         63.0
# 4044   https://cdn.sofifa.org/flags/111.png         26.0
# 4217   https://cdn.sofifa.org/flags/111.png         61.0
# 4504   https://cdn.sofifa.org/flags/111.png         69.0
# 5614   https://cdn.sofifa.org/flags/111.png         72.0
# 5913   https://cdn.sofifa.org/flags/111.png         37.0
# 5944   https://cdn.sofifa.org/flags/111.png         67.0
# 6021   https://cdn.sofifa.org/flags/111.png         66.0
# 6407   https://cdn.sofifa.org/flags/111.png         31.0
# 6717   https://cdn.sofifa.org/flags/111.png         66.0
# 6804   https://cdn.sofifa.org/flags/111.png         72.0
# 7102   https://cdn.sofifa.org/flags/111.png         66.0
# 8325   https://cdn.sofifa.org/flags/111.png         48.0
# 8441   https://cdn.sofifa.org/flags/111.png         65.0
# 9165   https://cdn.sofifa.org/flags/111.png         36.0
# 9228   https://cdn.sofifa.org/flags/111.png         58.0
# 9297   https://cdn.sofifa.org/flags/111.png         28.0
# 9514   https://cdn.sofifa.org/flags/111.png         66.0
# 9665   https://cdn.sofifa.org/flags/111.png         57.0
# 9911   https://cdn.sofifa.org/flags/111.png         34.0
# 10672  https://cdn.sofifa.org/flags/111.png         41.0
# 13891  https://cdn.sofifa.org/flags/111.png         57.0
#
#                          Club  BallControl  Acceleration  SprintSpeed  ...  \
# 26                  Liverpool         88.0          94.0         91.0  ...
# 752              Kasimpaşa SK         78.0          82.0         85.0  ...
# 959                   Arsenal         76.0          58.0         60.0  ...
# 1517     West Bromwich Albion         63.0          49.0         55.0  ...
# 2241           Olympiacos CFP         71.0          58.0         58.0  ...
# 2259                      NaN         77.0          78.0         84.0  ...
# 2334        Huddersfield Town         80.0          71.0         75.0  ...
# 3310              Aston Villa         72.0          76.0         76.0  ...
# 3616                     PAOK         71.0          80.0         78.0  ...
# 3929   Vancouver Whitecaps FC         68.0          52.0         51.0  ...
# 4044          Orlando City SC         62.0          64.0         64.0  ...
# 4217                      NaN         75.0          76.0         78.0  ...
# 4504                  Al Ahli         74.0          74.0         69.0  ...
# 5614                      NaN         66.0          77.0         74.0  ...
# 5913                      NaN         46.0          70.0         66.0  ...
# 5944           Wigan Athletic         66.0          65.0         67.0  ...
# 6021                      NaN         71.0          76.0         72.0  ...
# 6407                      NaN         24.0          60.0         55.0  ...
# 6717                      NaN         44.0          65.0         62.0  ...
# 6804                      NaN         70.0          75.0         74.0  ...
# 7102                  Al Ahli         66.0          79.0         68.0  ...
# 8325        Wycombe Wanderers         50.0          39.0         45.0  ...
# 8441                      NaN         60.0          66.0         62.0  ...
# 9165                      NaN         21.0          50.0         44.0  ...
# 9228               Ettifaq FC         54.0          73.0         69.0  ...
# 9297                 Al Wehda         20.0          42.0         44.0  ...
# 9514           IFK Norrköping         74.0          75.0         72.0  ...
# 9665    Medipol Başakşehir FK         63.0          76.0         79.0  ...
# 9911                      NaN         68.0          66.0         68.0  ...
# 10672                 Al Raed         48.0          61.0         58.0  ...
# 13891                KAA Gent         64.0          82.0         76.0  ...
#
#        GKReflexes  Position  Crossing  Volleys  HeadingAccuracy  ShortPassing  \
# 26           14.0        RM      78.0     73.0             59.0          82.0
# 752           7.0        LM      78.0     63.0             42.0          76.0
# 959           6.0       RDM      66.0     39.0             57.0          80.0
# 1517          8.0       LCB      18.0     23.0             77.0          59.0
# 2241         11.0        ST      30.0     74.0             82.0          63.0
# 2259          7.0        LM      66.0     54.0             64.0          69.0
# 2334         10.0        LM      71.0     61.0             63.0          76.0
# 3310          7.0        RB      72.0     60.0             72.0          73.0
# 3616         11.0        RM      76.0     63.0             33.0          72.0
# 3929          6.0       CDM      44.0     31.0             73.0          69.0
# 4044         15.0        CB      62.0     27.0             64.0          57.0
# 4217         13.0        LW      64.0     75.0             43.0          64.0
# 4504         11.0       RCM      63.0     57.0             64.0          72.0
# 5614         16.0        RB      70.0     62.0             50.0          64.0
# 5913          8.0        CB      38.0     42.0             64.0          45.0
# 5944         13.0       CDM      52.0     49.0             47.0          70.0
# 6021         14.0        LM      65.0     63.0             45.0          74.0
# 6407         79.0        GK      14.0     15.0             14.0          26.0
# 6717          7.0       RCB      34.0     33.0             63.0          59.0
# 6804          6.0        RB      63.0     56.0             63.0          72.0
# 7102          8.0        LB      65.0     35.0             65.0          62.0
# 8325         11.0       LCB      39.0     35.0             63.0          51.0
# 8441         13.0       LDM      60.0     49.0             63.0          68.0
# 9165         66.0        GK      10.0     17.0             18.0          39.0
# 9228         16.0        LB      64.0     41.0             52.0          64.0
# 9297         70.0        GK      10.0     12.0             22.0          19.0
# 9514         11.0        CM      61.0     56.0             35.0          71.0
# 9665          7.0        LB      65.0     22.0             59.0          60.0
# 9911         12.0        ST      51.0     52.0             70.0          52.0
# 10672        15.0       RCB      38.0     33.0             62.0          46.0
# 13891        13.0        LM      62.0     47.0             39.0          63.0
#
#        FKAccuracy  Finishing  Curve  Dribbling
# 26           60.0       90.0   83.0       89.0
# 752          63.0       75.0   63.0       83.0
# 959          56.0       57.0   69.0       68.0
# 1517         29.0       17.0   35.0       37.0
# 2241         44.0       75.0   66.0       70.0
# 2259         44.0       73.0   67.0       80.0
# 2334         63.0       61.0   70.0       81.0
# 3310         69.0       61.0   76.0       68.0
# 3616         74.0       60.0   70.0       76.0
# 3929         30.0       25.0   48.0       63.0
# 4044         30.0       27.0   30.0       49.0
# 4217         75.0       67.0   78.0       77.0
# 4504         76.0       68.0   65.0       71.0
# 5614         35.0       59.0   65.0       67.0
# 5913         37.0       37.0   46.0       38.0
# 5944         55.0       53.0   39.0       69.0
# 6021         62.0       68.0   59.0       69.0
# 6407         13.0       13.0   14.0       12.0
# 6717         22.0       25.0   34.0       42.0
# 6804         46.0       52.0   46.0       62.0
# 7102         42.0       45.0   69.0       66.0
# 8325         26.0       37.0   34.0       45.0
# 8441         61.0       63.0   40.0       69.0
# 9165         14.0       18.0   17.0       13.0
# 9228         32.0       61.0   31.0       60.0
# 9297         14.0        7.0   24.0       25.0
# 9514         56.0       57.0   67.0       80.0
# 9665         62.0       24.0   64.0       63.0
# 9911         32.0       66.0   46.0       64.0
# 10672        24.0       23.0   31.0       36.0
# 13891        43.0       54.0   58.0       66.0
#
# [31 rows x 41 columns]

# %%
#overall dist for egyption players
plt.figure(figsize=(10, 5))
plt.xticks(rotation= 90)
sns.barplot(data=egy, x='Name', y='Overall')
plt.show()

# %%
#age dist for egyption players
plt.figure(figsize=(10, 5))
plt.xticks(rotation= 90)
sns.barplot(data=egy, x='Name', y='Age')
plt.show()

# %% [markdown]
# And now .. what about all players ?

# %%
topplayers_df = pd.DataFrame.copy(df.sort_values(by = 'Overall' ,
                                                   ascending = False ).head(20))
topplayers_df
# Out:
#                  Name  Age  Overall Nationality  \
# 0            L. Messi   31       94   Argentina
# 1   Cristiano Ronaldo   33       94    Portugal
# 2           Neymar Jr   26       92      Brazil
# 3              De Gea   27       91       Spain
# 4        K. De Bruyne   27       91     Belgium
# 5           E. Hazard   27       91     Belgium
# 6           L. Modrić   32       91     Croatia
# 7           L. Suárez   31       91     Uruguay
# 8        Sergio Ramos   32       91       Spain
# 12           D. Godín   32       90     Uruguay
# 13        David Silva   32       90       Spain
# 9            J. Oblak   25       90    Slovenia
# 11           T. Kroos   28       90     Germany
# 10     R. Lewandowski   29       90      Poland
# 20    Sergio Busquets   29       89       Spain
# 24       G. Chiellini   33       89       Italy
# 23          S. Agüero   30       89   Argentina
# 22           M. Neuer   32       89     Germany
# 21          E. Cavani   31       89     Uruguay
# 16            H. Kane   24       89     England
#
#                                    Flag  LongPassing                 Club  \
# 0   https://cdn.sofifa.org/flags/52.png         87.0         FC Barcelona
# 1   https://cdn.sofifa.org/flags/38.png         77.0             Juventus
# 2   https://cdn.sofifa.org/flags/54.png         78.0  Paris Saint-Germain
# 3   https://cdn.sofifa.org/flags/45.png         51.0    Manchester United
# 4    https://cdn.sofifa.org/flags/7.png         91.0      Manchester City
# 5    https://cdn.sofifa.org/flags/7.png         83.0              Chelsea
# 6   https://cdn.sofifa.org/flags/10.png         88.0          Real Madrid
# 7   https://cdn.sofifa.org/flags/60.png         64.0         FC Barcelona
# 8   https://cdn.sofifa.org/flags/45.png         77.0          Real Madrid
# 12  https://cdn.sofifa.org/flags/60.png         70.0      Atlético Madrid
# 13  https://cdn.sofifa.org/flags/45.png         87.0      Manchester City
# 9   https://cdn.sofifa.org/flags/44.png         26.0      Atlético Madrid
# 11  https://cdn.sofifa.org/flags/21.png         93.0          Real Madrid
# 10  https://cdn.sofifa.org/flags/37.png         65.0    FC Bayern München
# 20  https://cdn.sofifa.org/flags/45.png         82.0         FC Barcelona
# 24  https://cdn.sofifa.org/flags/27.png         59.0             Juventus
# 23  https://cdn.sofifa.org/flags/52.png         64.0      Manchester City
# 22  https://cdn.sofifa.org/flags/21.png         59.0    FC Bayern München
# 21  https://cdn.sofifa.org/flags/60.png         52.0  Paris Saint-Germain
# 16  https://cdn.sofifa.org/flags/14.png         82.0    Tottenham Hotspur
#
#     BallControl  Acceleration  SprintSpeed  ...  GKReflexes  Position  \
# 0          96.0          91.0         86.0  ...         8.0        RF
# 1          94.0          89.0         91.0  ...        11.0        ST
# 2          95.0          94.0         90.0  ...        11.0        LW
# 3          42.0          57.0         58.0  ...        94.0        GK
# 4          91.0          78.0         76.0  ...        13.0       RCM
# 5          94.0          94.0         88.0  ...         8.0        LF
# 6          93.0          80.0         72.0  ...         9.0       RCM
# 7          90.0          86.0         75.0  ...        37.0        RS
# 8          84.0          76.0         75.0  ...        11.0       RCB
# 12         76.0          68.0         68.0  ...        15.0        CB
# 13         94.0          70.0         64.0  ...        12.0       LCM
# 9          16.0          43.0         60.0  ...        89.0        GK
# 11         90.0          64.0         62.0  ...        10.0       LCM
# 10         89.0          77.0         78.0  ...        10.0        ST
# 20         88.0          50.0         52.0  ...        13.0       CDM
# 24         57.0          63.0         75.0  ...         3.0       LCB
# 23         89.0          88.0         80.0  ...        14.0        ST
# 22         48.0          54.0         60.0  ...        87.0        GK
# 21         82.0          75.0         76.0  ...        10.0        LS
# 16         84.0          68.0         72.0  ...        11.0        ST
#
#     Crossing  Volleys  HeadingAccuracy  ShortPassing  FKAccuracy  Finishing  \
# 0       84.0     86.0             70.0          90.0        94.0       95.0
# 1       84.0     87.0             89.0          81.0        76.0       94.0
# 2       79.0     84.0             62.0          84.0        87.0       87.0
# 3       17.0     13.0             21.0          50.0        19.0       13.0
# 4       93.0     82.0             55.0          92.0        83.0       82.0
# 5       81.0     80.0             61.0          89.0        79.0       84.0
# 6       86.0     76.0             55.0          93.0        78.0       72.0
# 7       77.0     88.0             77.0          82.0        84.0       93.0
# 8       66.0     66.0             91.0          78.0        72.0       60.0
# 12      55.0     47.0             92.0          79.0        51.0       42.0
# 13      84.0     82.0             54.0          93.0        77.0       76.0
# 9       13.0     13.0             15.0          29.0        14.0       11.0
# 11      88.0     82.0             54.0          92.0        84.0       76.0
# 10      62.0     89.0             85.0          83.0        86.0       91.0
# 20      62.0     44.0             68.0          89.0        68.0       67.0
# 24      58.0     45.0             83.0          59.0        31.0       33.0
# 23      70.0     85.0             77.0          81.0        73.0       93.0
# 22      15.0     11.0             25.0          55.0        11.0       13.0
# 21      70.0     90.0             89.0          78.0        76.0       89.0
# 16      75.0     84.0             85.0          80.0        68.0       94.0
#
#     Curve  Dribbling
# 0    93.0       97.0
# 1    81.0       88.0
# 2    88.0       96.0
# 3    21.0       18.0
# 4    85.0       86.0
# 5    83.0       95.0
# 6    85.0       90.0
# 7    86.0       87.0
# 8    74.0       63.0
# 12   49.0       53.0
# 13   82.0       89.0
# 9    13.0       12.0
# 11   86.0       81.0
# 10   77.0       85.0
# 20   66.0       80.0
# 24   60.0       58.0
# 23   82.0       89.0
# 22   14.0       30.0
# 21   77.0       80.0
# 16   78.0       80.0
#
# [20 rows x 41 columns]

# %%
topplayers_n= topplayers_df['Nationality'].value_counts() #Nationalites of best players
topplayers_n
# Out:
# Spain        4
# Uruguay      3
# Argentina    2
# Belgium      2
# Germany      2
# Portugal     1
# Brazil       1
# Croatia      1
# Slovenia     1
# Poland       1
# Italy        1
# England      1
# Name: Nationality, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
sns.barplot(data= topplayers_df,
            x=topplayers_n.index,
           y=topplayers_n.values )
plt.show()

# %%
topplayers_c= topplayers_df['Club'].value_counts() #clubs of best players
topplayers_c
# Out:
# FC Barcelona           3
# Manchester City        3
# Real Madrid            3
# Juventus               2
# Paris Saint-Germain    2
# Atlético Madrid        2
# FC Bayern München      2
# Manchester United      1
# Chelsea                1
# Tottenham Hotspur      1
# Name: Club, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
sns.barplot(data= topplayers_df,
            x=topplayers_c.index,
           y=topplayers_c.values )
plt.show()

# %% [markdown]
# But (Overall) not realy everything .. we have to go deeper in players skills and abilities, and this for all players not topplayers only

# %%
abilities = ['Crossing', 'Finishing', 'HeadingAccuracy',
       'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
       'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed',
       'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping',
       'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions',
       'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking',
       'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
       'GKKicking', 'GKPositioning', 'GKReflexes']

# %%
# Create an empty dictionary to store results
top_players_by_ability = {}

for s in abilities:
    # Sort DataFrame by current ability in descending order
    top_players = df.sort_values(by=s, ascending=False)[['Name', 'Club', 'Nationality','Overall', s]].head(5)

    # Store the result in the dictionary
    top_players_by_ability[s] = top_players

# %% [markdown]
# lets use our loop to test some abilities

# %%
print(top_players_by_ability['Finishing'])
# Out:
#                  Name               Club Nationality  Overall  Finishing
# 0            L. Messi       FC Barcelona   Argentina       94       95.0
# 1   Cristiano Ronaldo           Juventus    Portugal       94       94.0
# 16            H. Kane  Tottenham Hotspur     England       89       94.0
# 23          S. Agüero    Manchester City   Argentina       89       93.0
# 7           L. Suárez       FC Barcelona     Uruguay       91       93.0

# %%
print(top_players_by_ability['ShotPower'])
# Out:
#                    Name                           Club Nationality  ShotPower
# 1     Cristiano Ronaldo                       Juventus    Portugal       95.0
# 378                Hulk               Shanghai SIPG FC      Brazil       94.0
# 1348          F. Guarín  Shanghai Greenland Shenhua FC    Colombia       93.0
# 890         L. Podolski                    Vissel Kobe     Germany       92.0
# 36              G. Bale                    Real Madrid       Wales       92.0

# %%
print(top_players_by_ability['Stamina'])
# Out:
#               Name              Club  Nationality  Overall  Stamina
# 14        N. Kanté           Chelsea       France       89     96.0
# 562      F. Kessié             Milan  Ivory Coast       79     96.0
# 751   M. Eggestein  SV Werder Bremen      Germany       78     96.0
# 190          Allan            Napoli       Brazil       83     95.0
# 1192     A. Schöpf     FC Schalke 04      Austria       77     95.0

# %%
print(top_players_by_ability['SprintSpeed'])
# Out:
#            Name                     Club Nationality  Overall  SprintSpeed
# 1968      Adama  Wolverhampton Wanderers       Spain       75         96.0
# 55      L. Sané          Manchester City     Germany       86         96.0
# 25    K. Mbappé      Paris Saint-Germain      France       88         96.0
# 1489   I. Bebou              Hannover 96        Togo       76         95.0
# 36      G. Bale              Real Madrid       Wales       88         95.0

# %%
print(top_players_by_ability['Vision'])
# Out:
#             Name             Club Nationality  Overall  Vision
# 0       L. Messi     FC Barcelona   Argentina       94    94.0
# 4   K. De Bruyne  Manchester City     Belgium       91    94.0
# 76       Iniesta      Vissel Kobe       Spain       86    93.0
# 13   David Silva  Manchester City       Spain       90    92.0
# 6      L. Modrić      Real Madrid     Croatia       91    92.0
